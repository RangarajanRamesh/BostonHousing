# %%
# Import libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import data
df = pd.read_csv("housing.csv")

# %%
# Initial view of data
df.head()
# RM is average number of rooms in local area
# LSTAT is percentage of lower income homeowners
# PTRatio ratio of students to teachers in local schools
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %% [markdown]
# ## Visualisation

# %%
df.plot(x ='RM', y='MEDV', kind = 'scatter')
plt.show()

# %%
df.plot(x ='LSTAT', y='MEDV', kind = 'scatter')
plt.show()

# %%
df.plot(x ='PTRATIO', y='MEDV', kind = 'scatter')
plt.show()

# %%
df.cov()
# Out:
#                    RM          LSTAT        PTRATIO          MEDV
# RM           0.414285      -2.789844      -0.413871  7.419786e+04
# LSTAT       -2.789844      50.154579       5.389359 -8.906976e+05
# PTRATIO     -0.413871       5.389359       4.457450 -1.811829e+05
# MEDV     74197.863207 -890697.598914 -181182.946420  2.733741e+10
